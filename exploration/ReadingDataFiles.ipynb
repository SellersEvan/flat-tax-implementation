# %% [markdown]
# # Reading CSV Tax Data Files
# We will be testing to ensure we can import and view the tax data csv files.

# %%
import pandas as pd

# %%
df2020 = pd.read_csv("../data/tax_data_2020.csv")
df2019 = pd.read_csv("../data/tax_data_2019.csv")

# %%
df2020.head(10)
# Out:
#    STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL        0         1  785000.0  519980.0   85690.0  165290.0
# 1          1    AL        0         2  554310.0  270870.0  121420.0  146470.0
# 2          1    AL        0         3  290630.0  113280.0  124770.0   44570.0
# 3          1    AL        0         4  181010.0   42010.0  120820.0   14410.0
# 4          1    AL        0         5  269080.0   31310.0  224330.0    8270.0
# 5          1    AL        0         6   81340.0    5000.0   72270.0     630.0
# 6          1    AL    35004         1    1460.0    1010.0     200.0     210.0
# 7          1    AL    35004         2    1400.0     760.0     280.0     310.0
# 8          1    AL    35004         3    1020.0     460.0     350.0     190.0
# 9          1    AL    35004         4     630.0     140.0     420.0      60.0
#
#         ELF    CPREP  ...   N85300    A85300    N11901     A11901    N11900  \
# ...

# %%
df2019.head(10)
# Out:
#    STATEFIPS STATE  zipcode  agi_stub        N1     mars1     MARS2     MARS4  \
# 0          1    AL        0         1  778210.0  491030.0   84770.0  189600.0
# 1          1    AL        0         2  525940.0  247140.0  123910.0  139860.0
# 2          1    AL        0         3  285700.0  105140.0  128140.0   44560.0
# 3          1    AL        0         4  179070.0   38820.0  123110.0   13740.0
# 4          1    AL        0         5  257010.0   28180.0  216740.0    7150.0
# 5          1    AL        0         6   74810.0    4540.0   66580.0     530.0
# 6          1    AL    35004         1    1450.0     990.0     180.0     250.0
# 7          1    AL    35004         2    1370.0     700.0     280.0     340.0
# 8          1    AL    35004         3     970.0     410.0     370.0     160.0
# 9          1    AL    35004         4     650.0     130.0     460.0      60.0
#
#         ELF    CPREP  ...   N85300    A85300    N11901    A11901    N11900  \
# ...

# %%
df2020.shape
# Out:
# (166452, 165)

# %%
df2019.shape
# Out:
# (166159, 152)

# %%
df2020.dtypes
# Out:
# STATEFIPS      int64
# STATE         object
# zipcode        int64
# agi_stub       int64
# N1           float64
#               ...
# A11900       float64
# N11902       float64
# A11902       float64
# N12000       float64
# A12000       float64
# Length: 165, dtype: object

# %%
df2019.dtypes
# Out:
# STATEFIPS      int64
# STATE         object
# zipcode        int64
# agi_stub       int64
# N1           float64
#               ...
# A11900       float64
# N11902       float64
# A11902       float64
# N12000       float64
# A12000       float64
# Length: 152, dtype: object

# %%
df2020["STATE"].value_counts().head(10)
# Out:
# TX    9702
# NY    9234
# CA    8898
# PA    8219
# IL    7379
# OH    5988
# FL    5526
# MI    5352
# MO    5351
# IA    4950
# Name: STATE, dtype: int64
